# %% [markdown]
# <a href="https://colab.research.google.com/github/Dattu219/Data-Science/blob/main/Grouping_Student_Alcohol_Consumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ex - GroupBy
#
# Check out [Alcohol Consumption Exercises Video Tutorial](https://youtu.be/az67CMdmS6s) to watch a data scientist go through the exercises

# %% [markdown]
# ### Introduction:
#
# GroupBy can be summarized as Split-Apply-Combine.
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out this [Diagram](http://i.imgur.com/yjNkiwL.png)
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
students = pd.read_csv('https://raw.githubusercontent.com/a-forty-two/COG_GN22CDBDS001_MARCH_22/main/student-mat.csv')
students.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
students.groupby('sex').health.mean()
# Out:
# sex
# F    3.365385
# M    3.764706
# Name: health, dtype: float64

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby('continent').wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
students.groupby('sex').health.describe()
# Out:
#      count      mean       std  min  25%  50%  75%  max
# sex
# F    208.0  3.365385  1.407761  1.0  2.0  3.0  5.0  5.0
# M    187.0  3.764706  1.343337  1.0  3.0  4.0  5.0  5.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
drinks.groupby('continent').mean()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF             61.471698        16.339623      16.264151
# AS             37.045455        60.840909       9.068182
# EU            193.777778       132.555556     142.222222
# OC             89.687500        58.437500      35.625000
# SA            175.083333       114.750000      62.416667
#
#            total_litres_of_pure_alcohol
# continent
# AF                             3.007547
# AS                             2.170455
# EU                             8.617778
# OC                             3.381250
# SA                             6.308333

# %%
students.groupby('sex').mean()
# Out:
#            age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# sex
# F    16.730769  2.668269  2.485577    1.408654   2.278846  0.302885  3.894231
# M    16.657754  2.839572  2.561497    1.491979   1.764706  0.368984  4.000000
#
#      freetime     goout      Dalc      Walc    health  absences         G1  \
# sex
# F    3.009615  3.028846  1.254808  1.956731  3.365385  6.216346  10.620192
# M    3.486631  3.197861  1.732620  2.663102  3.764706  5.144385  11.229947
#
#             G2         G3
# sex
# F    10.389423   9.966346
# M    11.074866  10.914439

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
drinks.groupby('continent').median()
# Out:
#            beer_servings  spirit_servings  wine_servings  \
# continent
# AF                  32.0              3.0            2.0
# AS                  17.5             16.0            1.0
# EU                 219.0            122.0          128.0
# OC                  52.5             37.0            8.5
# SA                 162.5            108.5           12.0
#
#            total_litres_of_pure_alcohol
# continent
# AF                                 2.30
# AS                                 1.20
# EU                                10.00
# OC                                 1.75
# SA                                 6.85

# %%
students.groupby('sex').median()
# Out:
#       age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# sex
# F    17.0   3.0   2.0         1.0        2.0       0.0     4.0       3.0
# M    16.0   3.0   3.0         1.0        2.0       0.0     4.0       3.0
#
#      goout  Dalc  Walc  health  absences    G1    G2    G3
# sex
# F      3.0   1.0   2.0     3.0       4.0  10.0  10.0  10.0
# M      3.0   1.0   3.0     4.0       4.0  11.0  11.0  11.0

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
drinks.groupby('continent').spirit_servings.agg(['mean', 'min', 'max'])
# Out:
#                  mean  min  max
# continent
# AF          16.339623    0  152
# AS          60.840909    0  326
# EU         132.555556    0  373
# OC          58.437500    0  254
# SA         114.750000   25  302

# %%
students.groupby('sex').health.agg(['mean','min','max'])
# Out:
#          mean  min  max
# sex
# F    3.365385    1    5
# M    3.764706    1    5
